# %%
from dotenv import load_dotenv
load_dotenv()
import os
os.environ['GROQ_API_KEY'] = os.getenv('GROQ_API_KEY')

# %%
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import OllamaEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_groq import ChatGroq

llm=ChatGroq(model="llama3-70b-8192")
embeddings=(
    OllamaEmbeddings(model="llama3.2:1b")  ##by default it ues llama2
)
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# C:\Users\amanm\AppData\Local\Temp\ipykernel_19844\2956569999.py:9: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaEmbeddings``.
#   OllamaEmbeddings(model="llama3.2:1b")  ##by default it ues llama2

# %%
# importing the module
from youtube_transcript_api import YouTubeTranscriptApi

# retrieve the available transcripts
transcript_list = YouTubeTranscriptApi.list_transcripts('pvnFaAIqTtQ')

# iterate over all available transcripts
for transcript in transcript_list:

    # the Transcript object provides metadata
    # properties
    print(
        transcript.video_id,
        transcript.language,
        transcript.language_code,
    
        # whether it has been manually created or
        # generated by YouTube
        transcript.is_generated,
        
        # whether this transcript can be translated
        # or not
        transcript.is_translatable,
        
        # a list of languages the transcript can be
        # translated to
        transcript.translation_languages,
    )

    # fetch the actual transcript data
    #print(transcript.fetch())

    # translating the transcript will return another
    # transcript object
    print(transcript.translate('en').fetch())

# you can also directly filter for the language you are
# looking for, using the transcript list
transcript = transcript_list.find_transcript(['en'])

# or just filter for manually created transcripts
transcript = transcript_list.find_manually_created_transcript(['en'])

# importing modules
from youtube_transcript_api import YouTubeTranscriptApi

# using the srt variable with the list of dictionaries
# obtained by the .get_transcript() function
srt = YouTubeTranscriptApi.get_transcript("pxiP-HJLCx0")

# creating or overwriting a file "subtitles.txt" with
# the info inside the context manager
with open("subtitles.txt", "w") as f:

        # iterating through each element of list srt
    for i in srt:
        # writing each element of srt on a new line
        f.write("{}\n".format(i))
# Out:
# pvnFaAIqTtQ Hindi (auto-generated) hi True True [_TranslationLanguage(language='Abkhazian', language_code='ab'), _TranslationLanguage(language='Afar', language_code='aa'), _TranslationLanguage(language='Afrikaans', language_code='af'), _TranslationLanguage(language='Akan', language_code='ak'), _TranslationLanguage(language='Albanian', language_code='sq'), _TranslationLanguage(language='Amharic', language_code='am'), _TranslationLanguage(language='Arabic', language_code='ar'), _TranslationLanguage(language='Armenian', language_code='hy'), _TranslationLanguage(language='Assamese', language_code='as'), _TranslationLanguage(language='Aymara', language_code='ay'), _TranslationLanguage(language='Azerbaijani', language_code='az'), _TranslationLanguage(language='Bangla', language_code='bn'), _TranslationLanguage(language='Bashkir', language_code='ba'), _TranslationLanguage(language='Basque', language_code='eu'), _TranslationLanguage(language='Belarusian', language_code='be'), _TranslationLanguage(language='Bhojpuri', language_code='bho'), _TranslationLanguage(language='Bosnian', language_code='bs'), _TranslationLanguage(language='Breton', language_code='br'), _TranslationLanguage(language='Bulgarian', language_code='bg'), _TranslationLanguage(language='Burmese', language_code='my'), _TranslationLanguage(language='Catalan', language_code='ca'), _TranslationLanguage(language='Cebuano', language_code='ceb'), _TranslationLanguage(language='Chinese (Simplified)', language_code='zh-Hans'), _TranslationLanguage(language='Chinese (Traditional)', language_code='zh-Hant'), _TranslationLanguage(language='Corsican', language_code='co'), _TranslationLanguage(language='Croatian', language_code='hr'), _TranslationLanguage(language='Czech', language_code='cs'), _TranslationLanguage(language='Danish', language_code='da'), _TranslationLanguage(language='Divehi', language_code='dv'), _TranslationLanguage(language='Dutch', language_code='nl'), _TranslationLanguage(language='Dzongkha', language_code='dz'), _TranslationLanguage(language='English', language_code='en'), _TranslationLanguage(language='Esperanto', language_code='eo'), _TranslationLanguage(language='Estonian', language_code='et'), _TranslationLanguage(language='Ewe', language_code='ee'), _TranslationLanguage(language='Faroese', language_code='fo'), _TranslationLanguage(language='Fijian', language_code='fj'), _TranslationLanguage(language='Filipino', language_code='fil'), _TranslationLanguage(language='Finnish', language_code='fi'), _TranslationLanguage(language='French', language_code='fr'), _TranslationLanguage(language='Ga', language_code='gaa'), _TranslationLanguage(language='Galician', language_code='gl'), _TranslationLanguage(language='Ganda', language_code='lg'), _TranslationLanguage(language='Georgian', language_code='ka'), _TranslationLanguage(language='German', language_code='de'), _TranslationLanguage(language='Greek', language_code='el'), _TranslationLanguage(language='Guarani', language_code='gn'), _TranslationLanguage(language='Gujarati', language_code='gu'), _TranslationLanguage(language='Haitian Creole', language_code='ht'), _TranslationLanguage(language='Hausa', language_code='ha'), _TranslationLanguage(language='Hawaiian', language_code='haw'), _TranslationLanguage(language='Hebrew', language_code='iw'), _TranslationLanguage(language='Hindi', language_code='hi'), _TranslationLanguage(language='Hmong', language_code='hmn'), _TranslationLanguage(language='Hungarian', language_code='hu'), _TranslationLanguage(language='Icelandic', language_code='is'), _TranslationLanguage(language='Igbo', language_code='ig'), _TranslationLanguage(language='Indonesian', language_code='id'), _TranslationLanguage(language='Inuktitut', language_code='iu'), _TranslationLanguage(language='Irish', language_code='ga'), _TranslationLanguage(language='Italian', language_code='it'), _TranslationLanguage(language='Japanese', language_code='ja'), _TranslationLanguage(language='Javanese', language_code='jv'), _ ...
# FetchedTranscript(snippets=[FetchedTranscriptSnippet(text='Hello welcome to Career 247 I am', start=3.919, duration=4.481), FetchedTranscriptSnippet(text='Prashant Dhawan Now recently the US government has', start=6.0, duration=5.04), FetchedTranscriptSnippet(text='released a very important report.', start=8.4, duration=4.48), FetchedTranscriptSnippet(text='This report has been prepared by the US Military', start=11.04, duration=4.719), FetchedTranscriptSnippet(text='and it is clearly written in it that Pakistan is', start=12.88, duration=5.36), FetchedTranscriptSnippet(text='upgrading its nuclear weapons', start=15.759, duration=5.52), FetchedTranscriptSnippet(text='with the help of China and you will see that', start=18.24, duration=5.119), FetchedTranscriptSnippet(text='many articles are being published on this.', start=21.279, duration=5.441), FetchedTranscriptSnippet(text='Upgrade Nukes Big China Support,', start=23.359, duration=5.521), FetchedTranscriptSnippet(text='here you will directly see that', start=26.72, duration=5.04), FetchedTranscriptSnippet(text='Pakistan is upgrading its', start=28.88, duration=6.08), FetchedTranscriptSnippet(text='nuclear weapons with help from', start=31.76, duration=6.319), FetchedTranscriptSnippet(text='China and it has been', start=34.96, duration=6.4), FetchedTranscriptSnippet(text='written in the US report about Pakistan that it is literally obsessed with', start=38.079, duration=5.521), FetchedTranscriptSnippet(text='India and after Operation Sindoor,', start=41.36, duration=4.879), FetchedTranscriptSnippet(text='you can assume that they would want to further', start=43.6, duration=5.2), FetchedTranscriptSnippet(text='advance their nuclear weapons, would like to', start=46.239, duration=4.721), FetchedTranscriptSnippet(text='increase their potency', start=48.8, duration=4.64), FetchedTranscriptSnippet(text='because Pakistan knows that the only thing that can', start=50.96, duration=4.88), FetchedTranscriptSnippet(text='save them from India is', start=53.44, duration=4.639), FetchedTranscriptSnippet(text='their nuclear weapons and', start=55.84, duration=4.239), FetchedTranscriptSnippet(text='see in this report, many important', start=58.079, duration=4.881), FetchedTranscriptSnippet(text='things have been written that', start=60.079, duration=5.281), FetchedTranscriptSnippet(text='what is the biggest threat for India today, what threats are arising for the US in the rest of the world, it is a', start=62.96, duration=4.159), FetchedTranscriptSnippet(text='very important report and', start=67.119, duration=4.561), FetchedTranscriptSnippet(text='I have actually seen it many times that people are', start=69.68, duration=4.0), FetchedTranscriptSnippet(text='posting on Twitter and other places that', start=71.68, duration=4.4), FetchedTranscriptSnippet(text='someone will release my video of 2021.', start=73.68, duration=5.759), FetchedTranscriptSnippet(text='There he will tell that in 2021', start=76.08, duration=5.76), FetchedTranscriptSnippet(text='Prashant Dhawan had given this report.   It was', start=79.439, duration=4.401), FetchedTranscriptSnippet(text='written here that in the year 2025 there was a', start=81.84, duration=3.76), FetchedTranscriptSnippet(text='conflict between India and Pakistan.', start=83.84, duration=4.16), FetchedTranscriptSnippet(text='And see, no one can make wild predictions.', start=85.6, duration=5.199), FetchedTranscriptSnippet(text='Whatever I tell you, whatever', start=88.0, duration=5.28), FetchedTranscriptSnippet(text='information, we discuss among ourselves', start=90.799, duration=4.0), FetchedTranscriptSnippet(text='because here I will use the word', start=93.28, duration=3.28), FetchedTranscriptSnippet(text='discuss because you people also contribute', start=94.799, duration=4.081), FetchedTranscriptSnippet(text='in the comment section.  It is purely', start=96.56, duration=5.199), FetchedTranscriptSnippet(text='based on geopolitical patterns,', s ...
# ---------------------------------------------------------------------------
# NoTranscriptFound                         Traceback (most recent call last)
# Cell In[5], line 39
#      35     print(transcript.translate('en').fetch())
#      37 # you can also directly filter for the language you are
#      38 # looking for, using the transcript list
# ---> 39 transcript = transcript_list.find_transcript(['en'])
#      41 # or just filter for manually created transcripts
#      42 transcript = transcript_list.find_manually_created_transcript(['en'])
#
# File c:\Users\amanm\Downloads\Machine Learning\Agentic AI\venvgenai\Lib\site-packages\youtube_transcript_api\_transcripts.py:265, in TranscriptList.find_transcript(self, language_codes)
#     254 def find_transcript(self, language_codes: Iterable[str]) -> Transcript:
#     255     """
#     256     Finds a transcript for a given language code. Manually created transcripts are returned first and only if none
#     257     are found, generated transcripts are used. If you only want generated transcripts use
#    (...)    263     :return: the found Transcript
#     264     """
# --> 265     return self._find_transcript(
#     266         language_codes,
#     267         [self._manually_created_transcripts, self._generated_transcripts],
#     268     )
#
# File c:\Users\amanm\Downloads\Machine Learning\Agentic AI\venvgenai\Lib\site-packages\youtube_transcript_api\_transcripts.py:306, in TranscriptList._find_transcript(self, language_codes, transcript_dicts)
#     303         if language_code in transcript_dict:
#     304             return transcript_dict[language_code]
# --> 306 raise NoTranscriptFound(self.video_id, language_codes, self)
#
# NoTranscriptFound:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=pvnFaAIqTtQ! This is most likely caused by:
#
# No transcripts were found for any of the requested language codes: ['en']
#
# For this video (pvnFaAIqTtQ) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
# None
#
# (GENERATED)
#  - hi ("Hindi (auto-generated)")[TRANSLATABLE]
#
# (TRANSLATION LANGUAGES)
#  - ab ("Abkhazian")
#  - aa ("Afar")
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - ba ("Bashkir")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - br ("Breton")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - dz ("Dzongkha")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fo ("Faroese")
#  - fj ("Fijian")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gaa ("Ga")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - iu ("Inuktitut")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kl ("Kalaallisut")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - kha ("Khasi")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - lua ("Luba-Lulua")
#  - luo ("Luo")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - gv ("Manx")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - mfe ("Morisyen")
#  - ne ("Nepali")
#  - new ("Newari")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - oc ("Occitan")
#  - or ("Odia")
#  - om ("Oromo")
#  - os ("Ossetic")
#  - pam ("Pampanga")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pt-PT ("Portuguese (Portugal)")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - rn ("Rundi")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sg ("Sango")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - crs ("Seselwa Creole French")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - ss ("Swati")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - bo ("Tibetan")
#  - ti ("Tigrinya")
#  - to ("Tongan")
#  - ts ("Tsonga")
#  - tn ("Tswana")
#  - tum ("Tumbuka")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - ve ("Venda")
#  - vi ("Vietnamese")
#  - war ("Waray")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - wo ("Wolof")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!

# %%
from youtube_transcript_api import YouTubeTranscriptApi

ytt_api = YouTubeTranscriptApi()
ytt_api.fetch('pvnFaAIqTtQ')
# Out:
# ---------------------------------------------------------------------------
# NoTranscriptFound                         Traceback (most recent call last)
# Cell In[8], line 4
#       1 from youtube_transcript_api import YouTubeTranscriptApi
#       3 ytt_api = YouTubeTranscriptApi()
# ----> 4 ytt_api.fetch('pvnFaAIqTtQ')
#
# File c:\Users\amanm\Downloads\Machine Learning\Agentic AI\venvgenai\Lib\site-packages\youtube_transcript_api\_api.py:80, in YouTubeTranscriptApi.fetch(self, video_id, languages, preserve_formatting)
#      59 def fetch(
#      60     self,
#      61     video_id: str,
#      62     languages: Iterable[str] = ("en",),
#      63     preserve_formatting: bool = False,
#      64 ) -> FetchedTranscript:
#      65     """
#      66     Retrieves the transcript for a single video. This is just a shortcut for
#      67     calling:
#    (...)     76     :param preserve_formatting: whether to keep select HTML text formatting
#      77     """
#      78     return (
#      79         self.list(video_id)
# ---> 80         .find_transcript(languages)
#      81         .fetch(preserve_formatting=preserve_formatting)
#      82     )
#
# File c:\Users\amanm\Downloads\Machine Learning\Agentic AI\venvgenai\Lib\site-packages\youtube_transcript_api\_transcripts.py:265, in TranscriptList.find_transcript(self, language_codes)
#     254 def find_transcript(self, language_codes: Iterable[str]) -> Transcript:
#     255     """
#     256     Finds a transcript for a given language code. Manually created transcripts are returned first and only if none
#     257     are found, generated transcripts are used. If you only want generated transcripts use
#    (...)    263     :return: the found Transcript
#     264     """
# --> 265     return self._find_transcript(
#     266         language_codes,
#     267         [self._manually_created_transcripts, self._generated_transcripts],
#     268     )
#
# File c:\Users\amanm\Downloads\Machine Learning\Agentic AI\venvgenai\Lib\site-packages\youtube_transcript_api\_transcripts.py:306, in TranscriptList._find_transcript(self, language_codes, transcript_dicts)
#     303         if language_code in transcript_dict:
#     304             return transcript_dict[language_code]
# --> 306 raise NoTranscriptFound(self.video_id, language_codes, self)
#
# NoTranscriptFound:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=pvnFaAIqTtQ! This is most likely caused by:
#
# No transcripts were found for any of the requested language codes: ('en',)
#
# For this video (pvnFaAIqTtQ) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
# None
#
# (GENERATED)
#  - hi ("Hindi (auto-generated)")[TRANSLATABLE]
#
# (TRANSLATION LANGUAGES)
#  - ab ("Abkhazian")
#  - aa ("Afar")
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - ba ("Bashkir")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - br ("Breton")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - dz ("Dzongkha")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fo ("Faroese")
#  - fj ("Fijian")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gaa ("Ga")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - iu ("Inuktitut")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kl ("Kalaallisut")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - kha ("Khasi")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - lua ("Luba-Lulua")
#  - luo ("Luo")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - gv ("Manx")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - mfe ("Morisyen")
#  - ne ("Nepali")
#  - new ("Newari")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - oc ("Occitan")
#  - or ("Odia")
#  - om ("Oromo")
#  - os ("Ossetic")
#  - pam ("Pampanga")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pt-PT ("Portuguese (Portugal)")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - rn ("Rundi")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sg ("Sango")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - crs ("Seselwa Creole French")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - ss ("Swati")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - bo ("Tibetan")
#  - ti ("Tigrinya")
#  - to ("Tongan")
#  - ts ("Tsonga")
#  - tn ("Tswana")
#  - tum ("Tumbuka")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - ve ("Venda")
#  - vi ("Vietnamese")
#  - war ("Waray")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - wo ("Wolof")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!

# %%
from langchain_community.document_loaders import YoutubeLoader
loader = YoutubeLoader.from_youtube_url(
    "https://www.youtube.com/watch?v=pvnFaAIqTtQ", add_video_info=False
)
docs = loader.load()
print(docs)
# Out:
# ---------------------------------------------------------------------------
# NoTranscriptFound                         Traceback (most recent call last)
# File c:\Users\amanm\Downloads\Machine Learning\Agentic AI\venvgenai\Lib\site-packages\langchain_community\document_loaders\youtube.py:267, in YoutubeLoader.load(self)
#     266 try:
# --> 267     transcript = transcript_list.find_transcript(self.language)
#     268 except NoTranscriptFound:
#
# File c:\Users\amanm\Downloads\Machine Learning\Agentic AI\venvgenai\Lib\site-packages\youtube_transcript_api\_transcripts.py:265, in TranscriptList.find_transcript(self, language_codes)
#     255 """
#     256 Finds a transcript for a given language code. Manually created transcripts are returned first and only if none
#     257 are found, generated transcripts are used. If you only want generated transcripts use
#    (...)    263 :return: the found Transcript
#     264 """
# --> 265 return self._find_transcript(
#     266     language_codes,
#     267     [self._manually_created_transcripts, self._generated_transcripts],
#     268 )
#
# File c:\Users\amanm\Downloads\Machine Learning\Agentic AI\venvgenai\Lib\site-packages\youtube_transcript_api\_transcripts.py:306, in TranscriptList._find_transcript(self, language_codes, transcript_dicts)
#     304             return transcript_dict[language_code]
# --> 306 raise NoTranscriptFound(self.video_id, language_codes, self)
#
# NoTranscriptFound:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=pvnFaAIqTtQ! This is most likely caused by:
#
# No transcripts were found for any of the requested language codes: ['en']
#
# For this video (pvnFaAIqTtQ) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
# None
#
# (GENERATED)
#  - hi ("Hindi (auto-generated)")[TRANSLATABLE]
#
# (TRANSLATION LANGUAGES)
#  - ab ("Abkhazian")
#  - aa ("Afar")
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - ba ("Bashkir")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - br ("Breton")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - dz ("Dzongkha")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fo ("Faroese")
#  - fj ("Fijian")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gaa ("Ga")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - iu ("Inuktitut")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kl ("Kalaallisut")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - kha ("Khasi")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - lua ("Luba-Lulua")
#  - luo ("Luo")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - gv ("Manx")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - mfe ("Morisyen")
#  - ne ("Nepali")
#  - new ("Newari")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - oc ("Occitan")
#  - or ("Odia")
#  - om ("Oromo")
#  - os ("Ossetic")
#  - pam ("Pampanga")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pt-PT ("Portuguese (Portugal)")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - rn ("Rundi")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sg ("Sango")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - crs ("Seselwa Creole French")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - ss ("Swati")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - bo ("Tibetan")
#  - ti ("Tigrinya")
#  - to ("Tongan")
#  - ts ("Tsonga")
#  - tn ("Tswana")
#  - tum ("Tumbuka")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - ve ("Venda")
#  - vi ("Vietnamese")
#  - war ("Waray")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - wo ("Wolof")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
#
# During handling of the above exception, another exception occurred:
#
# NoTranscriptFound                         Traceback (most recent call last)
# Cell In[9], line 5
#       1 from langchain_community.document_loaders import YoutubeLoader
#       2 loader = YoutubeLoader.from_youtube_url(
#       3     "https://www.youtube.com/watch?v=pvnFaAIqTtQ", add_video_info=False
#       4 )
# ----> 5 docs = loader.load()
#       6 print(docs)
#
# File c:\Users\amanm\Downloads\Machine Learning\Agentic AI\venvgenai\Lib\site-packages\langchain_community\document_loaders\youtube.py:269, in YoutubeLoader.load(self)
#     267     transcript = transcript_list.find_transcript(self.language)
#     268 except NoTranscriptFound:
# --> 269     transcript = transcript_list.find_transcript(["en"])
#     271 if self.translation is not None:
#     272     transcript = transcript.translate(self.translation)
#
# File c:\Users\amanm\Downloads\Machine Learning\Agentic AI\venvgenai\Lib\site-packages\youtube_transcript_api\_transcripts.py:265, in TranscriptList.find_transcript(self, language_codes)
#     254 def find_transcript(self, language_codes: Iterable[str]) -> Transcript:
#     255     """
#     256     Finds a transcript for a given language code. Manually created transcripts are returned first and only if none
#     257     are found, generated transcripts are used. If you only want generated transcripts use
#    (...)    263     :return: the found Transcript
#     264     """
# --> 265     return self._find_transcript(
#     266         language_codes,
#     267         [self._manually_created_transcripts, self._generated_transcripts],
#     268     )
#
# File c:\Users\amanm\Downloads\Machine Learning\Agentic AI\venvgenai\Lib\site-packages\youtube_transcript_api\_transcripts.py:306, in TranscriptList._find_transcript(self, language_codes, transcript_dicts)
#     303         if language_code in transcript_dict:
#     304             return transcript_dict[language_code]
# --> 306 raise NoTranscriptFound(self.video_id, language_codes, self)
#
# NoTranscriptFound:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=pvnFaAIqTtQ! This is most likely caused by:
#
# No transcripts were found for any of the requested language codes: ['en']
#
# For this video (pvnFaAIqTtQ) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
# None
#
# (GENERATED)
#  - hi ("Hindi (auto-generated)")[TRANSLATABLE]
#
# (TRANSLATION LANGUAGES)
#  - ab ("Abkhazian")
#  - aa ("Afar")
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - ba ("Bashkir")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - br ("Breton")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - dz ("Dzongkha")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fo ("Faroese")
#  - fj ("Fijian")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gaa ("Ga")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - iu ("Inuktitut")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kl ("Kalaallisut")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - kha ("Khasi")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - lua ("Luba-Lulua")
#  - luo ("Luo")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - gv ("Manx")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - mfe ("Morisyen")
#  - ne ("Nepali")
#  - new ("Newari")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - oc ("Occitan")
#  - or ("Odia")
#  - om ("Oromo")
#  - os ("Ossetic")
#  - pam ("Pampanga")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pt-PT ("Portuguese (Portugal)")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - rn ("Rundi")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sg ("Sango")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - crs ("Seselwa Creole French")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - ss ("Swati")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - bo ("Tibetan")
#  - ti ("Tigrinya")
#  - to ("Tongan")
#  - ts ("Tsonga")
#  - tn ("Tswana")
#  - tum ("Tumbuka")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - ve ("Venda")
#  - vi ("Vietnamese")
#  - war ("Waray")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - wo ("Wolof")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!

# %%
from langchain_community.document_loaders.sitemap import SitemapLoader
sitemap_loader = SitemapLoader(web_path="https://api.python.langchain.com/sitemap.xml")

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
docs = sitemap_loader.load()
docs
# Out:
# Fetching pages: 100%|##########| 18/18 [00:08<00:00,  2.11it/s]
# [Document(metadata={'source': 'https://api.python.langchain.com/en/latest/', 'loc': 'https://api.python.langchain.com/en/latest/', 'lastmod': '2024-12-09T14:05:30.040082+00:00', 'changefreq': 'weekly', 'priority': '1'}, page_content='\n\n\n\n\n\n\n\n\n\nLangChain Python API Reference Documentation.\n\n\nYou will be automatically redirected to the new location of this page.\n\n'),
#  Document(metadata={'source': 'https://api.python.langchain.com/en/v0.1.9/', 'loc': 'https://api.python.langchain.com/en/v0.1.9/', 'lastmod': '2024-02-23T06:02:18.866357+00:00', 'changefreq': 'daily', 'priority': '0.9'}, page_content='\n\n\n\n\n  Documentation page not found\n - Read the Docs\n\n\n\n\n\n\n\n\n\n\n\n\n\n      \n  404\n\n    \n  \n  Documentation page not found\n\n\n                \n\napi.python.langchain.com\n\n\n\n    The documentation page you requested does not exist or may have been removed.\n  \n\n\n\n\n      \n      Hosted by\n      \n      \n\n\n\n\n\n\n\n\n\n\n'),
#  Document(metadata={'source': 'https://api.python.langchain.com/en/v0.1.8/', 'loc': 'https://api.python.langchain.com/en/v0.1.8/', 'lastmod': '2024-02-19T21:06:18.171997+00:00', 'changefreq': 'monthly', 'priority': '0.8'}, page_content='\n\n\n\n\n  Documentation page not found\n - Read the Docs\n\n\n\n\n\n\n\n\n\n\n\n\n\n      \n  404\n\n    \n  \n  Documentation page not found\n\n\n                \n\napi.python.langchain.com\n\n\n\n    The documentation page you requested does not exist or may have been removed.\n  \n\n\n\n\n      \n      Hosted by\n      \n      \n\n\n\n\n\n\n\n\n\n\n'),
#  Document(metadata={'source': 'https://api.python.langchain.com/en/v0.1.7/', 'loc': 'https://api.python.langchain.com/en/v0.1.7/', 'lastmod': '2024-02-13T21:18:21.910004+00:00', 'changefreq': 'monthly', 'priority': '0.7'}, page_content='\n\n\n\n\n  Documentation page not found\n - Read the Docs\n\n\n\n\n\n\n\n\n\n\n\n\n\n      \n  404\n\n    \n  \n  Documentation page not found\n\n\n                \n\napi.python.langchain.com\n\n\n\n    The documentation page you requested does not exist or may have been removed.\n  \n\n\n\n\n      \n      Hosted by\n      \n      \n\n\n\n\n\n\n\n\n\n\n'),
#  Document(metadata={'source': 'https://api.python.langchain.com/en/v0.1.6/', 'loc': 'https://api.python.langchain.com/en/v0.1.6/', 'lastmod': '2024-02-09T01:10:49.509254+00:00', 'changefreq': 'monthly', 'priority': '0.6'}, page_content='\n\n\n\n\n  Documentation page not found\n - Read the Docs\n\n\n\n\n\n\n\n\n\n\n\n\n\n      \n  404\n\n    \n  \n  Documentation page not found\n\n\n                \n\napi.python.langchain.com\n\n\n\n    The documentation page you requested does not exist or may have been removed.\n  \n\n\n\n\n      \n      Hosted by\n      \n      \n\n\n\n\n\n\n\n\n\n\n'),
#  Document(metadata={'source': 'https://api.python.langchain.com/en/v0.1.5/', 'loc': 'https://api.python.langchain.com/en/v0.1.5/', 'lastmod': '2024-02-01T16:21:13.145703+00:00', 'changefreq': 'monthly', 'priority': '0.5'}, page_content='\n\n\n\n\n  Documentation page not found\n - Read the Docs\n\n\n\n\n\n\n\n\n\n\n\n\n\n      \n  404\n\n    \n  \n  Documentation page not found\n\n\n                \n\napi.python.langchain.com\n\n\n\n    The documentation page you requested does not exist or may have been removed.\n  \n\n\n\n\n      \n      Hosted by\n      \n      \n\n\n\n\n\n\n\n\n\n\n'),
#  Document(metadata={'source': 'https://api.python.langchain.com/en/v0.1.2/', 'loc': 'https://api.python.langchain.com/en/v0.1.2/', 'lastmod': '2024-01-22T17:36:35.659273+00:00', 'changefreq': 'monthly', 'priority': '0.4'}, page_content='\n\n\n\n\n  Documentation page not found\n - Read the Docs\n\n\n\n\n\n\n\n\n\n\n\n\n\n      \n  404\n\n    \n  \n  Documentation page not found\n\n\n                \n\napi.python.langchain.com\n\n\n\n    The documentation page you requested does not exist or may have been removed.\n  \n\n\n\n\n      \n      Hosted by\n      \n      \n\n\n\n\n\n\n\n\n\n\n'),
#  Document(metadata={'source': 'https://api.python.langchain.com/en/v0.1.1/', 'loc': 'https://api.python.langchain.com/en/v0.1.1/', 'lastmod': '2024-01-16T18:43:35.851795+00:00', 'changefreq': 'monthly', 'priority': '0.3'}, page_content='\n\n\n\n\n  Documentation page not found\n - Read the Docs\n\n\n\n\n\n\n\n\n\n\n\n\n\n      \n  404\n\n    \n  \n  Documentation page not found\n\n\n                \n\napi.python.langchain.com\n\n\n\n    The documentation page you requested does not exist or may have been removed.\n  \n\n\n\n\n      \n      Hosted by\n      \n      \n\n\n\n\n\n\n\n\n\n\n'),
#  Document(metadata={'source': 'https://api.python.langchain.com/en/v0.1.0/', 'loc': 'https://api.python.langchain.com/en/v0.1.0/', 'lastmod': '2024-01-06T01:18:49.366168+00:00', 'changefreq': 'monthly', 'priority': '0.2'}, page_content='\n\n\n\n\n  Documentation page not found\n - Read the Docs\n\n\n\n\n\n\n\n\n\n\n\n\n\n      \n  404\n\n    \n  \n  Documentation page not found\n\n\n                \n\napi.python.langchain.com\n\n\n\n    The documentation page you requested does not exist or may have been removed.\n  \n\n\n\n\n      \n      Hosted by\n      \n      \n\n\n\n\n\n\n\n\n\n\n'),
#  Document(metadata={'source': 'https://api.python.langchain.com/en/v0.1/', 'loc': 'https://api.python.langchain.com/en/v0.1/', 'lastmod': '2024-05-15T00:26:41.998433+00:00', 'changefreq': 'monthly', 'priority': '0.1'}, page_content='\n\n\n\n\n\n\n\n\n\nLangChain Python API Reference Documentation.\n\n\nYou will be automatically redirected to the new location of this page.\n\n'),
#  Document(metadata={'source': 'https://api.python.langchain.com/en/v0.0.354/', 'loc': 'https://api.python.langchain.com/en/v0.0.354/', 'lastmod': '2024-01-03T18:40:55.084986+00:00', 'changefreq': 'monthly', 'priority': '0.1'}, page_content='\n\n\n\n\n\n\n\n\n\nLangChain Python API Reference Documentation.\n\n\nYou will be automatically redirected to the new location of this page.\n\n'),
#  Document(metadata={'source': 'https://api.python.langchain.com/en/v0.0.352/', 'loc': 'https://api.python.langchain.com/en/v0.0.352/', 'lastmod': '2023-12-20T15:31:56.280682+00:00', 'changefreq': 'monthly', 'priority': '0.1'}, page_content='\n\n\n\n\n  Documentation page not found\n - Read the Docs\n\n\n\n\n\n\n\n\n\n\n\n\n\n      \n  404\n\n    \n  \n  Documentation page not found\n\n\n                \n\napi.python.langchain.com\n\n\n\n    The documentation page you requested does not exist or may have been removed.\n  \n\n\n\n\n      \n      Hosted by\n      \n      \n\n\n\n\n\n\n\n\n\n\n'),
#  Document(metadata={'source': 'https://api.python.langchain.com/en/v0.0.351/', 'loc': 'https://api.python.langchain.com/en/v0.0.351/', 'lastmod': '2023-12-18T21:46:31.820833+00:00', 'changefreq': 'monthly', 'priority': '0.1'}, page_content='\n\n\n\n\n  Documentation page not found\n - Read the Docs\n\n\n\n\n\n\n\n\n\n\n\n\n\n      \n  404\n\n    \n  \n  Documentation page not found\n\n\n                \n\napi.python.langchain.com\n\n\n\n    The documentation page you requested does not exist or may have been removed.\n  \n\n\n\n\n      \n      Hosted by\n      \n      \n\n\n\n\n\n\n\n\n\n\n'),
#  Document(metadata={'source': 'https://api.python.langchain.com/en/v0.0.350/', 'loc': 'https://api.python.langchain.com/en/v0.0.350/', 'lastmod': '2023-12-12T18:13:58.539153+00:00', 'changefreq': 'monthly', 'priority': '0.1'}, page_content='\n\n\n\n\n  Documentation page not found\n - Read the Docs\n\n\n\n\n\n\n\n\n\n\n\n\n\n      \n  404\n\n    \n  \n  Documentation page not found\n\n\n                \n\napi.python.langchain.com\n\n\n\n    The documentation page you requested does not exist or may have been removed.\n  \n\n\n\n\n      \n      Hosted by\n      \n      \n\n\n\n\n\n\n\n\n\n\n'),
#  Document(metadata={'source': 'https://api.python.langchain.com/en/v0.0.348/', 'loc': 'https://api.python.langchain.com/en/v0.0.348/', 'lastmod': '2023-12-07T22:56:33.184738+00:00', 'changefreq': 'monthly', 'priority': '0.1'}, page_content='\n\n\n\n\n  Documentation page not found\n - Read the Docs\n\n\n\n\n\n\n\n\n\n\n\n\n\n      \n  404\n\n    \n  \n  Documentation page not found\n\n\n                \n\napi.python.langchain.com\n\n\n\n    The documentation page you requested does not exist or may have been removed.\n  \n\n\n\n\n      \n      Hosted by\n      \n      \n\n\n\n\n\n\n\n\n\n\n'),
#  Document(metadata={'source': 'https://api.python.langchain.com/en/v0.0.347/', 'loc': 'https://api.python.langchain.com/en/v0.0.347/', 'lastmod': '2023-12-07T00:24:30.505583+00:00', 'changefreq': 'monthly', 'priority': '0.1'}, page_content='\n\n\n\n\n  Documentation page not found\n - Read the Docs\n\n\n\n\n\n\n\n\n\n\n\n\n\n      \n  404\n\n    \n  \n  Documentation page not found\n\n\n                \n\napi.python.langchain.com\n\n\n\n    The documentation page you requested does not exist or may have been removed.\n  \n\n\n\n\n      \n      Hosted by\n      \n      \n\n\n\n\n\n\n\n\n\n\n'),
#  Document(metadata={'source': 'https://api.python.langchain.com/en/v0.0.346/', 'loc': 'https://api.python.langchain.com/en/v0.0.346/', 'lastmod': '2023-12-05T19:42:23.397670+00:00', 'changefreq': 'monthly', 'priority': '0.1'}, page_content='\n\n\n\n\n  Documentation page not found\n - Read the Docs\n\n\n\n\n\n\n\n\n\n\n\n\n\n      \n  404\n\n    \n  \n  Documentation page not found\n\n\n                \n\napi.python.langchain.com\n\n\n\n    The documentation page you requested does not exist or may have been removed.\n  \n\n\n\n\n      \n      Hosted by\n      \n      \n\n\n\n\n\n\n\n\n\n\n'),
#  Document(metadata={'source': 'https://api.python.langchain.com/en/v0.0.344/', 'loc': 'https://api.python.langchain.com/en/v0.0.344/', 'lastmod': '2023-12-01T00:02:18.921994+00:00', 'changefreq': 'monthly', 'priority': '0.1'}, page_content='\n\n\n\n\n  Documentation page not found\n - Read the Docs\n\n\n\n\n\n\n\n\n\n\n\n\n\n      \n  404\n\n    \n  \n  Documentation page not found\n\n\n                \n\napi.python.langchain.com\n\n\n\n    The documentation page you requested does not exist or may have been removed.\n  \n\n\n\n\n      \n      Hosted by\n      \n      \n\n\n\n\n\n\n\n\n\n\n')]
